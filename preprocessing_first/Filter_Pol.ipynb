# %%
import pandas as pd

# %%
comments = pd.read_csv('/data/tmip/root_comments_rank10.csv')

# %%
articles = pd.read_csv('/data/tmip/raw/articles-standardized.csv')
pol_a = articles[articles['article_url'].str.contains("https://www.theguardian.com/politics/")]

# %%
comments = comments[comments['article_id'].isin(pol_a['article_id'])]

# %%
comments
# Out:
#          Unnamed: 0  Unnamed: 0.1  article_id  author_id  comment_id  \
# 1488           9150         13000         168       2068    12650257
# 1489           9152         13002         168        228    12650312
# 1490           9154         13004         168        243    12649474
# 1491           9155         13005         168        261    12649916
# 1492           9162         13012         168       5546    12650316
# 1493           9163         13013         168       5547    12650301
# 1494           9164         13014         168       5548    12649762
# 1495           9165         13015         168       5549    12648185
# 1496           9166         13016         168        601    12650330
# 1497           9167         13017         168        722    12648828
# 3294          21404         25254         369       2917    10162077
# 3295          21415         25265         369       5996    10162064
# 3296          21428         25278         369        724    10162137
# ...

# %%
comments.to_csv('/data/tmip/root_comments_pol.csv')
